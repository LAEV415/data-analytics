# %% [markdown]
# # Lab 1 Excercise 2.C
# ## Working with defining custom functions
# ### Author: Luis Angel Espinosa Villicana

# %% [markdown]
# 3. In a code cell, create a function named favorite_things() and include three
# parameters for name, movie, and music.

# %% [markdown]
# a) This function should return 3 lines of text listing your name, your favorite movie,
# and your favorite musician / band.

# %%
def favorite_things(name, movie, music):
    return f'Name is {name}' '\n' f'Favorite movie is {movie}' '\n' f'Favorite music is {music}'

# %% [markdown]
# b) In a print statement, call the function with appropriate arguments to display the
# output.

# %%
print(favorite_things("Luis", "Star Wars", "Hip-Hop"))
# Out:
# Name is Luis
# Favorite movie is Star Wars
# Favorite music is Hip-Hop

# %% [markdown]
# 4. In another code cell, create a function named why_im_here() with one parameter
# called purpose.

# %% [markdown]
# a) This function should return the value supplied to purpose, which will be a
# sentence that describes why you joined the Year Up United Data Analyst program.

# %%
def why_im_here(purpose):
    return purpose

# %% [markdown]
# b) In a print statement, call the function with appropriate arguments to display the
# output.

# %%
answer = "I chose Year Up United's Data Analyst program to leverage data-driven insights for meaningful, large-scale community impact."
print(why_im_here(answer))
# Out:
# I chose Year Up United's Data Analyst program to leverage data-driven insights for meaningful, large-scale community impact.

# %% [markdown]
# 5. In another code cell, create a function named favorite_place(), with two
# parameters, place and why.

# %% [markdown]
# a) With this function, you will output a sentence that will describe one of your
# favorite places to visit and why, e.g. One of my favorite places is ____ because
# ____.

# %%
def favorite_place(place, why):
    # fav_places = {
    #     'Santa Cruz' : 'it was one of our main vacation spots as a kid; I was able to enjoy the thrill of rides and the relaxation of being at a cool beach on a hot day.',
    #     'The Pier' : 'attending high school near the piers of SF, I made many memories in that area. From running to IHop for free pancakes to celebrating birthdays.',
    #     'Lake Tahoe' : "it's a nice place to get away and refresh especially when it's snowing. There's opportunities to go sledding or just throw snowballs at siblings."
    # }
    return print(f'One of my favorite places is {place} because {why}')

# %% [markdown]
# b) Add two code cells to test. In one, call the function with one or your favorite places
# and display the output.

# %%
favorite_place('Santa Cruz', 'it was one of our main vacation spots as a kid; I was able to enjoy the thrill of rides and the relaxation of being at a cool beach on a hot day.')
# Out:
# One of my favorite places is Santa Cruz because it was one of our main vacation spots as a kid; I was able to enjoy the thrill of rides and the relaxation of being at a cool beach on a hot day.

# %% [markdown]
# c) Then in the next code cell, provide a different place name and reason why it’s one
# of your favorites.

# %%
favorite_place('The Pier', 'attending high school near the piers of SF, I made many memories in that area. From running to IHop for free pancakes to celebrating birthdays.')
# Out:
# One of my favorite places is The Pier because attending high school near the piers of SF, I made many memories in that area. From running to IHop for free pancakes to celebrating birthdays.

# %% [markdown]
# 6. When you are done, review your code with your peer group. How did each of you
# approach these functions? Which ended up seeming to be the most efficient? Which
# would be the most readable / reusable to another coder if the function were shared?

# %% [markdown]
# We approached these functions in a similar fashion. A lot of overthinking went into this as returning what was being inputted without altering much of it seemed a bit awkward but it makes sense if there's a large amount of inputs that need to be formatted/structured in a specific way. It's most efficient to just have the solution in the return statement unless it's a large amount of characters. It could help be more readable by assigning strings to variables first and then outputting those variables.
